# %%
from helpers import get_matrix_from_features, d_prime_with_plt
import matplotlib.pyplot as plt
import numpy as np

# %%
X_old = np.load('../old_features_test.npy')[:472]
X_new = np.load('../new_features_test.npy')[:472]

S = get_matrix_from_features(X_new, X_old)

plt.imshow(S)
plt.colorbar()
plt.show()

# %%
d_prime = d_prime_with_plt(S, 'feats_ignacio.png')
d_prime
# Out:
# 1.6386385113671909
